# %%
TERRAFORM_FOLDER = '/terraform/eberron-agent'

# %%
# !terraform -chdir=$TERRAFORM_FOLDER destroy -auto-approve
# Out:
# module.eks.module.eks_managed_node_group["regular_nodes"].data.aws_partition.current: Reading...
# module.eks.module.eks_managed_node_group["regular_nodes"].data.aws_iam_policy_document.assume_role_policy[0]: Reading...
# module.eks.module.eks_managed_node_group["gpu_nodes"].data.aws_partition.current: Reading...
# data.aws_availability_zones.available: Reading...
# module.eks.data.aws_iam_policy_document.assume_role_policy[0]: Reading...
# module.eks.module.kms.data.aws_caller_identity.current[0]: Reading...
# module.eks.data.aws_partition.current[0]: Reading...
# module.eks.aws_cloudwatch_log_group.this[0]: Refreshing state... [id=/aws/eks/eberron-agent/cluster]
# module.vpc.aws_vpc.this[0]: Refreshing state... [id=vpc-0612bdf98e6143693]
# module.eks.data.aws_iam_policy_document.assume_role_policy[0]: Read complete after 0s [id=2830595799]
# module.eks.module.eks_managed_node_group["gpu_nodes"].data.aws_iam_policy_document.assume_role_policy[0]: Reading...
# ...
